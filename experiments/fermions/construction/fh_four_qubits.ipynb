# %%
from typing import List
import numpy as np
import stim
import networkx as nx
from stimcirq import stim_circuit_to_cirq_circuit, cirq_circuit_to_stim_circuit
import cirq
from encoded.code_extension import encoding_unitary_for_new_stabilizer
from encoded.utils import cirq_pauli_string_to_stim, stim_pauli_string_to_cirq, get_observables
from encoded.diagonalizing_circuit import get_measurement_circuit

# %%
generators = [
    stim.PauliString("ZIZI"),
    stim.PauliString("IZIZ")
]

# %%
logical_ops = get_observables(generators)
for lop in logical_ops:
    print(lop)
# Out:
# (stim.PauliString("+_X_X"), stim.PauliString("+___Z"))
# (stim.PauliString("+X_X_"), stim.PauliString("+__Z_"))
